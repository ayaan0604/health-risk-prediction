# %%
import pandas as pd 
import numpy as np

# %%
data=pd.read_csv("datasets/cardio_train.csv", sep=";")
data
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
data.shape
# Out:
# (70000, 13)

# %%
data.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %%
#converting height from cm into m

data["height"]=data["height"]/float(100)
data.head(5)
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2    1.68    62.0    110     80            1     1      0
# 1   1  20228       1    1.56    85.0    140     90            3     1      0
# 2   2  18857       1    1.65    64.0    130     70            3     1      0
# 3   3  17623       2    1.69    82.0    150    100            1     1      0
# 4   4  17474       1    1.56    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
#calculating the bmi feature

data["bmi"]=data["weight"]/(data["height"]**2)
data.head(5)
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2    1.68    62.0    110     80            1     1      0
# 1   1  20228       1    1.56    85.0    140     90            3     1      0
# 2   2  18857       1    1.65    64.0    130     70            3     1      0
# 3   3  17623       2    1.69    82.0    150    100            1     1      0
# 4   4  17474       1    1.56    56.0    100     60            1     1      0
#
#    alco  active  cardio        bmi
# 0     0       1       0  21.967120
# 1     0       1       1  34.927679
# 2     0       0       1  23.507805
# 3     0       1       1  28.710479
# 4     0       0       0  23.011177

# %%
#converting age from days to years
data["age"]=data["age"]//365

# %%
data.head(5)
# Out:
#    id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0   50       2    1.68    62.0    110     80            1     1      0
# 1   1   55       1    1.56    85.0    140     90            3     1      0
# 2   2   51       1    1.65    64.0    130     70            3     1      0
# 3   3   48       2    1.69    82.0    150    100            1     1      0
# 4   4   47       1    1.56    56.0    100     60            1     1      0
#
#    alco  active  cardio        bmi
# 0     0       1       0  21.967120
# 1     0       1       1  34.927679
# 2     0       0       1  23.507805
# 3     0       1       1  28.710479
# 4     0       0       0  23.011177

# %%
data['age'].describe()
# Out:
# count    70000.000000
# mean        52.840671
# std          6.766774
# min         29.000000
# 25%         48.000000
# 50%         53.000000
# 75%         58.000000
# max         64.000000
# Name: age, dtype: float64

# %%
X=data[['gender', 'age', 'smoke', 'alco', 'active', 'bmi']]
Y=data['cardio']
X.head(10)
# Out:
#    gender  age  smoke  alco  active        bmi
# 0       2   50      0     0       1  21.967120
# 1       1   55      0     0       1  34.927679
# 2       1   51      0     0       0  23.507805
# 3       2   48      0     0       1  28.710479
# 4       1   47      0     0       0  23.011177
# 5       1   60      0     0       0  29.384676
# 6       1   60      0     0       1  37.729725
# 7       2   61      0     0       1  29.983588
# 8       1   48      0     0       1  28.440955
# 9       1   54      0     0       0  25.282570

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   gender  70000 non-null  int64
#  1   age     70000 non-null  int64
#  2   smoke   70000 non-null  int64
#  3   alco    70000 non-null  int64
#  4   active  70000 non-null  int64
#  5   bmi     70000 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 3.2 MB

# %%
X["male"]=[1 if x==2 else 0 for x in X["gender"]]
X["female"]=[1 if x==1 else 0 for x in X["gender"]]
X.head(10)
# Out:
# C:\Users\AYAAN\AppData\Local\Temp\ipykernel_8796\1162495046.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["male"]=[1 if x==2 else 0 for x in X["gender"]]
# C:\Users\AYAAN\AppData\Local\Temp\ipykernel_8796\1162495046.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["female"]=[1 if x==1 else 0 for x in X["gender"]]
#    gender  age  smoke  alco  active        bmi  male  female
# 0       2   50      0     0       1  21.967120     1       0
# ...

# %%
X.drop("gender",axis=1, inplace=True)
X.head(10)
# Out:
# C:\Users\AYAAN\AppData\Local\Temp\ipykernel_8796\3929022498.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.drop("gender",axis=1, inplace=True)
#    age  smoke  alco  active        bmi  male  female
# 0   50      0     0       1  21.967120     1       0
# 1   55      0     0       1  34.927679     0       1
# 2   51      0     0       0  23.507805     0       1
# 3   48      0     0       1  28.710479     1       0
# 4   47      0     0       0  23.011177     0       1
# 5   60      0     0       0  29.384676     0       1
# 6   60      0     0       1  37.729725     0       1
# 7   61      0     0       1  29.983588     1       0
# 8   48      0     0       1  28.440955     0       1
# 9   54      0     0       0  25.282570     0       1

# %%
#trying with lLogisticRegression
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test =train_test_split(X,Y, random_state=42, test_size=0.2)

# %%
model=LogisticRegression(max_iter=1000)

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 0], shape=(14000,))

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.6251428571428571

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[4296, 2692],
#        [2556, 4456]])

# %%
#trying with decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier(max_depth=5,random_state=42)

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
dt_pred=dt.predict(x_test)

# %%
accuracy_score(y_test, dt_pred)
# Out:
# 0.629

# %%
confusion_matrix(y_test, dt_pred)
# Out:
# array([[4210, 2778],
#        [2416, 4596]])

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.61      0.62      6988
#            1       0.62      0.64      0.63      7012
#
#     accuracy                           0.62     14000
#    macro avg       0.63      0.62      0.62     14000
# weighted avg       0.63      0.62      0.62     14000

# %%
#trying xgboost

# %%
# !pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/56.8 MB ? eta -:--:--
#    --- ------------------------------------ 5.2/56.8 MB 53.0 MB/s eta 0:00:01
#    ------- -------------------------------- 11.0/56.8 MB 36.2 MB/s eta 0:00:02
#    -------- ------------------------------- 12.1/56.8 MB 26.0 MB/s eta 0:00:02
#    -------- ------------------------------- 12.1/56.8 MB 26.0 MB/s eta 0:00:02
#    -------- ------------------------------- 12.6/56.8 MB 13.1 MB/s eta 0:00:04
#    -------- ------------------------------- 12.6/56.8 MB 13.1 MB/s eta 0:00:04
#    --------- ------------------------------ 12.8/56.8 MB 10.9 MB/s eta 0:00:05
#    --------- ------------------------------ 13.1/56.8 MB 9.3 MB/s eta 0:00:05
#    --------- ------------------------------ 13.4/56.8 MB 8.1 MB/s eta 0:00:06
#    --------- ------------------------------ 13.6/56.8 MB 7.2 MB/s eta 0:00:07
#    --------- ------------------------------ 14.2/56.8 MB 6.4 MB/s eta 0:00:07
# ...

# %%
from xgboost import XGBClassifier

# %% [markdown]
# xgmodel=XGBClassifier(
#     n_estimators=200,       # number of trees
#     max_depth=5,            # depth of each tree
#     learning_rate=0.1,      # step size shrinkage
#     subsample=0.8,          # row sampling for each tree
#     colsample_bytree=0.8,   # feature sampling for each tree
#     random_state=42,
#     use_label_encoder=False,
#     eval_metric='logloss'
#     )

# %%
xgmodel.fit(x_train, y_train)
# Out:
# C:\Users\AYAAN\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:06:16] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
xg_pred=xgmodel.predict(x_test)

# %%
accuracy_score(y_test, xg_pred)
# Out:
# 0.6297857142857143

# %%
print(classification_report(y_test, xg_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.61      0.62      6988
#            1       0.63      0.65      0.64      7012
#
#     accuracy                           0.63     14000
#    macro avg       0.63      0.63      0.63     14000
# weighted avg       0.63      0.63      0.63     14000

# %%
import pickle

# %%
filename = 'model/logistic_regression_cardio_model_v2.pkl'
with open(filename, 'wb') as file:
    pickle.dump(model, file)

# %%
#cannot exceed 62% accuracy with current input features
